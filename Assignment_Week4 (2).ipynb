# %% [markdown]
# # Vacuum agent

# %% [markdown]
# ![VacuumCleaner(SimpleReflexAgent).png](data:image/png;base64,...)

# %% [markdown]
# ## My vacuum agent

# %% [markdown]
# > Indented block![myVacuumCleaner(SimpleReflexAgent).png](data:image/png;base64,...)

# %% [markdown]
# https://github.com/Laksheeta/Simple-Reflex-Vaccum-Agent/blob/main/vacuum.ipynb

# %%
import random


class Environment(object):
    def __init__(self):
        self.locationCondition = {'A': '0', 'B': '0'}
        self.locationCondition['A'] = random.randint(0, 1)
        self.locationCondition['B'] = random.randint(0, 1)


class SimpleReflexVacuumAgent(Environment):
    def __init__(self, Environment):
        print (Environment.locationCondition)
        Score = 0
        vacuumLocation = random.randint(0, 1)
        if vacuumLocation == 0:
            print ("Vacuum is randomly placed at Location A.")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0
                Score += 1
                print ("Location A has been Cleaned.")
            print ("Moving to Location B...")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0;
                Score += 1
                print ("Location B has been Cleaned.")
            print("Environment is Clean.")

        elif vacuumLocation == 1:
            print ("Vacuum randomly placed at Location B.")
            print ("Location B is Dirty.") if Environment.locationCondition['B'] == 1 else print("Location B is Clean.")
            if Environment.locationCondition['B'] == 1:
                Environment.locationCondition['B'] = 0
                Score += 1
                print ("Location B has been Cleaned.")
            print ("Moving to Location A...")
            print ("Location A is Dirty.") if Environment.locationCondition['A'] == 1 else print("Location A is Clean.")
            if Environment.locationCondition['A'] == 1:
                Environment.locationCondition['A'] = 0;
                Score += 1
                print ("Location A has been Cleaned.")
            print("Environment is Clean.")

        print (Environment.locationCondition)
        print ("Performance Measurement: " + str(Score))


theEnvironment = Environment()
theVacuum = SimpleReflexVacuumAgent(theEnvironment)
# Out:
# {'A': 0, 'B': 1}
# Vacuum is randomly placed at Location A.
# Location A is Clean.
# Moving to Location B...
# Location B is Dirty.
# Location B has been Cleaned.
# Environment is Clean.
# {'A': 0, 'B': 0}
# Performance Measurement: 1

# %% [markdown]
# ## Environment terminology

# %% [markdown]
# *   Fully Observable
# *   Single agent
# *   Discrete
# *   Deterministic
# *   Benign
# *   Static

# %% [markdown]
# # Assignment

# %% [markdown]
# ## 1: Google Assistance

# %% [markdown]
# ![go1.png](data:image/png;base64,...)

# %% [markdown]
# ### My Google Assistance Agent

# %% [markdown]
# ![cats1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Environment terminology

# %% [markdown]
# * Partially observable
# * Multiple
# * Deterministic & Stochastic
# * Dynamic
# * Continuous
# * Benign
# * Sequential

# %% [markdown]
# ##2: Autonomous Drone

# %% [markdown]
# ![21.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### My Autonomous Drone Agent

# %% [markdown]
# ![l';ol.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Environment terminology

# %% [markdown]
# * Partially observable
# * Multiple
# * Deterministic
# * Dynamic
# * Continuous
# * Benign
# * Sequential
