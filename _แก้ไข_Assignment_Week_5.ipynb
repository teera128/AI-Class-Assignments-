# %% [markdown]
# # Assignment

# %% [markdown]
# ## Search Tree

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Breadth-First Search

# %% [markdown]
# ### BFC Search

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### BFS Coding

# %%
graph = {
  'Frankfurt' : ['Kassel','Mannheim','Wurzburg'],
  'Kassel' : ['Munchen'],
  'Mannheim' : ['Karlruhe'],
  'Karlruhe' : ['Augsburg'],
  'Augsburg' : ['Munchen'],
  'Wurzburg' : ['Erfurt','Nurnberg'],
  'Erfurt' : [],
  'Nurnberg' : ['Munchen','Stuttgart'],
  'Stuttgart' : [],
  'Munchen' : [],
}

visited = [] # List for visited nodes.
queue = []     #Initialize a queuenm

def bfs(visited, graph, node): #function for BFS
  visited.append(node)
  queue.append(node)

  while queue:          # Creating loop to visit each node
    m = queue.pop(0)
    print (m, end = " ")

    for neighbour in graph[m]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

# Driver Code
print("Following is the Breadth-First Search")
bfs(visited, graph, 'Frankfurt')    # function calling
# Out:
# Following is the Breadth-First Search
# Frankfurt Kassel Mannheim Wurzburg Munchen Karlruhe Erfurt Nurnberg Augsburg Stuttgart

# %% [markdown]
# ### Pros & Cons of BFS

# %% [markdown]
# Pros
#
# *   หาก Goal อยู่ใกล้ Root จะสามารถเจอได้เร็ว
# *   สามารถเจอ Goal ได้แน่นอน
# *   ไม่มีปัญหากับ Infinite Loop
#
# Cons
#
# *   หาก Goal อยู่ชั้นล่าง จะสามารถเจอได้ช้า
# *   ไม่การันตีว่าจะได้ Optimal Point

# %% [markdown]
# ##Depth-First Search

# %% [markdown]
# ### DFS Search

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### DFS Coding

# %%
# Using a Python dictionary to act as an adjacency list
graph = {
  'Frankfurt' : ['Kassel','Mannheim','Wurzburg'],
  'Kassel' : ['Munchen'],
  'Mannheim' : ['Karlruhe'],
  'Karlruhe' : ['Augsburg'],
  'Augsburg' : ['Munchen'],
  'Wurzburg' : ['Erfurt','Nurnberg'],
  'Erfurt' : [],
  'Nurnberg' : ['Munchen','Stuttgart'],
  'Stuttgart' : [],
  'Munchen' : [],
}

visited = set() # Set to keep track of visited nodes of graph.

def dfs(visited, graph, node):  #function for dfs
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbour in graph[node]:
            dfs(visited, graph, neighbour)

# Driver Code
print("Following is the Depth-First Search")
dfs(visited, graph, 'Frankfurt')
# Out:
# Following is the Depth-First Search
# Frankfurt
# Kassel
# Munchen
# Mannheim
# Karlruhe
# Augsburg
# Wurzburg
# Erfurt
# Nurnberg
# Stuttgart

# %% [markdown]
# ### Pros & Cons of DFS

# %% [markdown]
# Pros
#
# *   หาก Goal อยู่ node ซ้ายสุด จะสามารถเจอได้เร็ว
# *   สามารถเจอ Goal ได้แน่นอน หากไม่มี Infinite Loop
#
# Cons
#
# *   หาก Goal อยู่ node ขวาสุดจะใช้เวลาเจอนาน
# *   ไม่การันตีว่าจะได้ Optimal Point
# *   หากเกิด Infinite Loop จะไม่มีทางเจอ Goal

# %% [markdown]
# ## Uniform Cost Search

# %% [markdown]
# ### UCS Search

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Pros & Cons of UFS

# %% [markdown]
# Pros
#
# *   การันตีว่าจะได้ Optimal Point
# *   สามารถเจอ Goal ได้แน่นอน
# *   ดู node ที่ Cost น้อยที่สุดก่อน
#
# Cons
#
# *   มีความซับซ้อน หากคำนวนโดยไม่ใช้การเขียนโค้ด
