# %% [markdown]
# #Formula

# %% [markdown]
# \begin{array}{|c|c|} \hline
# xxx & yyy & column3 & column4 \\ \hline
# 0 & bar & foo & bar \\
# 10 & bar & foo & bar \\
# foo & bar & foo & bar \\
# foo & bar & foo & bar \\ \hline
# \end{array}

# %% [markdown]
# conditional probability
#
# $P (\mathrm{x} = x; \mathrm{y} = y) = P(x) P(y)$ denotes the probability that $\mathrm{x} = x$ and $\mathrm{y} = y$

# %% [markdown]
# $$\color{orange}{\forall x \in \mathrm{x}, P(\mathrm{x} = x) = \displaystyle\sum_{y} P(\mathrm{x} = x, \mathrm{y} = y) = \displaystyle\sum_{y} P( x) P(y)) \tag{1}}$$

# %% [markdown]
# $$\color{red}{P(\mathrm{x} = x \ | \ \mathrm{y} = y) = \frac{P(\mathrm{x} = x, \mathrm{y} = y)}{P(\mathrm{y} = y)} \tag{3a}}$$

# %% [markdown]
# $$\color{blue}{P(\mathrm{x} = x \ | \ \mathrm{y} = y) = \frac{P( x \cap y)}{P(y)} \tag{3b}}$$

# %% [markdown]
# \begin{align*}
# 2x - 5y &=  8 \\
# 3x + 9y &=  -12
# \end{align*}

# %% [markdown]
# \begin{align*}
# P(soldout \ | \ fall) &= \frac{P(soldout,fall)}{P(fall)} \\
#  &=  0.987
# \end{align*}

# %% [markdown]
# #Assignment 1

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Cookies & Semester & P(t,w) \\ \hline
# in-stock & fall & 0.10 \\
# in-stock & spring & 0.20 \\
# in-stock & summer & 0.30 \\
# sold-out & fall & 0.23 \\
# sold-out & spring & 0.13 \\
# sold-out & summer & 0.03 \\ \hline
# \end{array}

# %% [markdown]
# ##1. P(spring)

# %% [markdown]
# $P (\mathrm{Spring}) = 0.33$

# %% [markdown]
# ##2. P(sold_out|fall)

# %% [markdown]
# \begin{align*}
# P(sold-out \ | \ fall) &= \frac{P(soldout,fall)}{P(fall)} \\
#  &=  0.697
# \end{align*}

# %% [markdown]
# ##3. Marginalization Table

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Cookies & P(t) \\ \hline
# in-stock & 0.60 \\
# sold-out & 0.39 \\ \hline
# \end{array}

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Semester & P(w) \\ \hline
# fall & 0.33 \\
# spring & 0.33 \\
# summer & 0.33 \\ \hline
# \end{array}

# %% [markdown]
# ##4. Normalization Table (Conditional Probability)

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Cookies & P(t|fall) \\ \hline
# in-stock & 0.303 \\
# sold-out & 0.696 \\ \hline
# \end{array}

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Cookies & P(t|spring) \\ \hline
# in-stock & 0.606 \\
# sold-out & 0.393 \\ \hline
# \end{array}

# %% [markdown]
# \begin{array}{|c|c|} \hline
# Cookies & P(t|summer) \\ \hline
# in-stock & 0.909\\
# sold-out & 0.090 \\ \hline
# \end{array}

# %% [markdown]
# #Assignment 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \begin{align*}
# P(haircut \ | \ permanent) &= \frac{P(haircut,permanent)}{P(permanent)} \\
#  &=  0.667
# \end{align*}

# %% [markdown]
# #Assignment 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \begin{align*}
# P(rides \ bike \ | \ crossing \ guard) &= \frac{P(rides \ bike,crossing \ guard)}{P(crossing \ guard)} \\
#  &=  0.25
# \end{align*}

# %% [markdown]
# #Assignment 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# \begin{align*}
# P(crash \ | \ on-315) &= \frac{P(on-315 \ | \ crash) \ P(crash)}{P(on-315)} \\
#  &=  0.114
# \end{align*}
